# %% [markdown]
# # Scrape Online Travel Agent (OTA) Property Prices
#
# @Nileka add a description here
#
# ### Execute the cell below once to turn off debugging

# %%
'''
    WARNING CONTROL to display or ignore all warnings
'''
import warnings; warnings.simplefilter('ignore')     #switch betweeb 'default' and 'ignore'

''' Set debug flag to view extended error messages; else set it to False to turn off debugging mode '''
debug = True

# %% [markdown]
# ## Initialize the OTA scrape class

# %%
import sys
sys.path.insert(1, '../lib')
import otaWebScraper as otaws
import datetime

if debug:
    import importlib
    otaws = importlib.reload(otaws)
    
clsScraper = otaws.OTAWebScraper()
# Out:
# All packages in ExtractLoadTransform loaded successfully!

# %% [markdown]
# ## Initialize the set of OTA URL for Scraping

# %%
path = "../data"
file = "properties.json"
start_date = datetime.date(2022,8,25)
end_date = datetime.date(2022,8,27)

scrape_crietia_dict = {"pageOffset":25,
                        "pageUpperLimit":150,
                        "startDate": start_date,
                        "endDate" : end_date,
             }

_, _ota_url_parameterized_list  = clsScraper.build_scrape_url_list(dirPath=path, fileName=file, **scrape_crietia_dict)

#print(_ota_url_parameterized_list)
print("Completed parameterizing urls with %d instances." % (len(_ota_url_parameterized_list)))
# Out:
# Loaded 2 properties to begin scraping OTA data.
# Processing booking.com ...
# Processing hotels.com ...
# Completed parameterizing urls with 84 instances.

# %%
path = "../data"
file = "properties.json"
property_dict = clsScraper.load_ota_list(dirPath=path, fileName=file)
_scrape_tags_df = clsScraper.get_scrape_html_tags(property_dict)
print(_scrape_tags_df)
# Out:
#      variable   tag                   code          ota
# 0      header   div            .d20f4628d0  booking.com
# 0        name  span  fcab3ed991 a23c043802  booking.com
# 0   room_type  span             df597226dd  booking.com
# 0   room_rate   div  fcab3ed991 bd73d13072  booking.com
# 0   room_type  span            .d20f4628d0   hotels.com
# 0   room_rate   div            .d20f4628d0   hotels.com
# 0  hotel_name  span  fcab3ed991 a23c043802   hotels.com

# %%
path = "../data/prices"
fPrefix = "Price"
counter = 0
for ota_url in _ota_url_parameterized_list:
    counter += 1
    fname = fPrefix+str(counter)+".csv"
    saveTo = clsScraper.scrape_data_to_csv(ota_url['url'],fname, path)
    print("data save to %s" % (saveTo))
# Out:
# [<div class="d20f4628d0"><div class="f9d4f2568d"><div class="c90a25d457"><a aria-hidden="true" href="https://www.booking.com/hotel/us/downtown-grand-an-ascend-collection-member.en-gb.html?label=New_English_EN_USD_27026936425-5WQxik*5vqjOdJbH0vs4ggS217290507247%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi2642648920%3Atidsa-302962658775%3Alp9069783%3Ali%3Adec%3Adm&amp;sid=6ffc8b26c9bbcc341461e4b1a20a470c&amp;aid=318615&amp;ucfs=1&amp;arphpl=1&amp;checkin=2022-08-25&amp;checkout=2022-08-26&amp;dest_id=20079110&amp;dest_type=city&amp;group_adults=1&amp;req_adults=1&amp;no_rooms=1&amp;group_children=0&amp;req_children=0&amp;hpos=1&amp;hapos=1&amp;sr_order=popularity&amp;nflt=ht_id%3D204&amp;srpvid=6f6c173f9e730029&amp;srepo
g viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M23.555 8.729a1.505 1.505 0 0 0-1.406-.98h-6.087a.5.5 0 0 1-.472-.334l-2.185-6.193a1.5 1.5 0 0 0-2.81 0l-.005.016-2.18 6.177a.5.5 0 0 1-.471.334H1.85A1.5 1.5 0 0 0 .887 10.4l5.184 4.3a.5.5 0 0 1 .155.543l-2.178 6.531a1.5 1.5 0 0 0 2.31 1.684l5.346-3.92a.5.5 0 0 1 .591 0l5.344 3.919a1.5 1.5 0 0 0 2.312-1.683l-2.178-6.535a.5.5 0 0 1 .155-.543l5 ...
# data save to ../data/prices/Price1.csv

# %% [markdown]
# # DEPRECATED

# %%
path = "../data"
#file = "property_urls.csv"
file = "properties.json"

clsScraper = otaws.OTAWebScraper()
#property_dict = clsScraper.load_ota_list(dirPath=path, fileName=file)

# %%
_ota_input_param_list, _ota_scrape_params = clsScraper.get_scrape_params(property_dict)
print(_ota_input_param_list)
print(_ota_scrape_param_df)
# Out:
# [{'ota': 'hotels.com', 'page': None, 'checkin': None, 'checkout': None, 'location': None, 'somekey': None}, {'ota': 'hotels.com', 'page': None, 'checkin': None, 'checkout': None, 'location': None, 'somekey': None}]
#         source       param   tag                  class
# 0  booking.com   room_rate   div            .d20f4628d0
# 1  booking.com   room_type  span            .d20f4628d0
# 2  booking.com  hotel_name  span  fcab3ed991 a23c043802
# 3   hotels.com   room_rate   div            .d20f4628d0
# 4   hotels.com   room_type  span            .d20f4628d0
# 5   hotels.com  hotel_name  span  fcab3ed991 a23c043802

# %%
import pandas as pd

param_dict = {}
tag_dict = {}
_l_tag=[]
for prop_detail in property_dict:
    for detail in property_dict[prop_detail]:
        url = detail['url']
        for param in detail['inputs']:
            param_dict[param] = None
        for tag in detail['outputs']:
            for rate in tag['room_rate']:
                for key,value in rate.items():
                    tag_dict = {"source":prop_detail,
                                "param" : "room_rate",
                                "tag" : key,
                                "class" : value
                               }
                    _l_tag.append(tag_dict)
            for rate in tag['room_type']:
                for key,value in rate.items():
                    tag_dict = {"source":prop_detail,
                                "param" : "room_type",
                                "tag" : key,
                                "class" : value
                               }
                    _l_tag.append(tag_dict)
            for rate in tag['hotel_name']:
                for key,value in rate.items():
                    tag_dict = {"source":prop_detail,
                                "param" : "hotel_name",
                                "tag" : key,
                                "class" : value
                               }
                    _l_tag.append(tag_dict)

tag_df = pd.DataFrame(_l_tag,columns=["source","param","tag","class"])
print(tag_df)
# Out:
#         source       param   tag                  class
# 0  booking.com   room_rate   div            .d20f4628d0
# 1  booking.com   room_type  span            .d20f4628d0
# 2  booking.com  hotel_name  span  fcab3ed991 a23c043802

# %%
param_dict = {"page":"25",
              "checkin":"2022-08-30",
              "checkout":"2022-09-2",
              "location":"Las Vegas",
             }
for url in _l_urls:
    new_url = clsScraper.insert_params_in_url(url[0],**param_dict)
    print(new_url)
# Out:
# b
