# %% [markdown]
# # Looping page and check-in & check-out dates
#
# * ERROR - output has only one date range

# %%
from bs4 import BeautifulSoup # Import for Beautiful Soup
import requests # Import for requests
import lxml # Import for lxml parser
import csv
from csv import writer
import datetime
from datetime import date, timedelta

check_in = date(2022, 8, 23)
check_in_last= date(2022, 12, 30)

check_out = date(2022, 8, 24)
check_out_last= date(2022, 12, 31)

delta= timedelta(days=1)

page = 0

while check_in != check_in_last and check_out != check_out_last and page != 175:
    
    url = f"https://www.booking.com/searchresults.en-gb.html?label=New_English_EN_USD_27026936425-5WQxik*5vqjOdJbH0vs4ggS217290507247%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi2642648920%3Atidsa-302962658775%3Alp9069783%3Ali%3Adec%3Adm&sid=6ffc8b26c9bbcc341461e4b1a20a470c&aid=318615&tmpl=searchresults&checkin={check_in}&checkout={check_out}&class_interval=1&dest_id=20079110&dest_type=city&group_adults=1&group_children=0&highlighted_hotels=580015&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&sb_travel_purpose=leisure&shw_aparth=1&slp_r_match=0&src=searchresults&srpvid=b3c92b578f3900dd&ss=Las+Vegas&ssb=empty&ssne=Las+Vegas&ssne_untouched=Las+Vegas&changed_currency=1&selected_currency=USD&nflt=%3Bht_id%3D204&offset={page}"
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.5112.102 Safari/537.36 Edg/104.0.1293.63'}
    
    page = page + 25
    check_in += delta 
    check_out += delta
    

    # Request for the URL
    response = requests.get(url, headers=headers)
    # Make it a soup
    soup = BeautifulSoup(response.text,"lxml")
    lists = soup.select(".d20f4628d0")



    with open('Book3.csv', 'a', encoding='utf8', newline='') as f:
        fieldnames = ['Date', 'Hotel', 'Room Type', 'Rate']
        thewriter = csv.DictWriter(f, fieldnames=fieldnames)

        for list in lists:
            hotel = list.find('div', class_='fcab3ed991 a23c043802').text
            room_type = list.find('span', class_='df597226dd').text
            room_rate = list.find('span', class_='fcab3ed991 bd73d13072').text
            currentDateTime = datetime.datetime.now()

            thewriter.writerow({'Date': currentDateTime, 'Hotel':hotel, 'Room Type':room_type , 'Rate': room_rate})

page= page +1
check_in += delta 
check_out += delta

# %% [markdown]
# # Include check-in and check-out date - scrape from search box
#
# * ERROR - all date ranges are not been extracted

# %%
from bs4 import BeautifulSoup # Import for Beautiful Soup
import requests # Import for requests
import lxml # Import for lxml parser
import csv
from csv import writer
import datetime
from datetime import date, timedelta

check_in = date(2022, 8, 23)
check_in_last= date(2022, 12, 30)

check_out = date(2022, 8, 24)
check_out_last= date(2022, 12, 31)

delta= timedelta(days=1)

page = 0

while check_in != check_in_last and check_out != check_out_last and page != 175:
    
    url = f"https://www.booking.com/searchresults.en-gb.html?label=New_English_EN_USD_27026936425-5WQxik*5vqjOdJbH0vs4ggS217290507247%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi2642648920%3Atidsa-302962658775%3Alp9069783%3Ali%3Adec%3Adm&sid=6ffc8b26c9bbcc341461e4b1a20a470c&aid=318615&tmpl=searchresults&checkin={check_in}&checkout={check_out}&class_interval=1&dest_id=20079110&dest_type=city&group_adults=1&group_children=0&highlighted_hotels=580015&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A&sb_price_type=total&sb_travel_purpose=leisure&shw_aparth=1&slp_r_match=0&src=searchresults&srpvid=b3c92b578f3900dd&ss=Las+Vegas&ssb=empty&ssne=Las+Vegas&ssne_untouched=Las+Vegas&changed_currency=1&selected_currency=USD&nflt=%3Bht_id%3D204&offset={page}"
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.5112.102 Safari/537.36 Edg/104.0.1293.63'}
    
    page = page + 25
    check_in += delta 
    check_out += delta
    

    # Request for the URL
    response = requests.get(url, headers=headers)
    # Make it a soup
    soup = BeautifulSoup(response.text,"lxml")
    lists = soup.select(".d20f4628d0")
    lists2 = soup.select(".ffa9856b86 c43efd0a38 ed26a8024c")


with open('Book5.csv', 'a', encoding='utf8', newline='') as f:
    fieldnames = ['Date', 'Hotel', 'Room Type', 'Rate', 'Check-in date', 'Check-out date']
    thewriter = csv.DictWriter(f, fieldnames=fieldnames)

    for list in lists:
        hotel = list.find('div', class_='fcab3ed991 a23c043802').text
        room_type = list.find('span', class_='df597226dd').text
        room_rate = list.find('span', class_='fcab3ed991 bd73d13072').text
        currentDateTime = datetime.datetime.now()


    for list2 in lists2:
        check_in = list2.find('div', class_='b9c5dd7ce2').text
        check_out = list2.find('div', class_='b9c5dd7ce2').text

    thewriter.writerow({'Date': currentDateTime, 'Hotel':hotel, 'Room Type':room_type , 'Rate': room_rate, 'Check-in date': check_in, 'Check-out date': check_out})

# %% [markdown]
# # Only loop pages - data for one check-in date only

# %%
from bs4 import BeautifulSoup # Import for Beautiful Soup
import requests # Import for requests
import lxml # Import for lxml parser

import datetime


page= 0

while page != 150:
    url = f"https://www.booking.com/searchresults.en-gb.html?aid=318615&label=New_English_EN_USD_27026936425-5WQxik%2A5vqjOdJbH0vs4ggS217290507247%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi2642648920%3Atidsa-302962658775%3Alp9069783%3Ali%3Adec%3Adm&sid=6ffc8b26c9bbcc341461e4b1a20a470c&tmpl=searchresults&checkin=2022-08-23&checkout=2022-08-24&class_interval=1&dest_id=20079110&dest_type=city&dtdisc=0&group_adults=1&group_children=0&highlighted_hotels=580015&inac=0&index_postcard=0&label_click=undef&nflt=%3Bht_id%3D204&no_rooms=1&offset=0&postcard=0&raw_dest_type=city&room1=A&sb_price_type=total&sb_travel_purpose=leisure&shw_aparth=1&slp_r_match=0&src=searchresults&srpvid=dabe52a917840104&ss=Las%20Vegas&ss_all=0&ssb=empty&sshis=0&ssne=Las%20Vegas&ssne_untouched=Las%20Vegas&changed_currency=1&selected_currency=USD&offset={page}"
    page = page + 25

    headers = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36'}
    response = requests.get(url, headers=headers)
    # Make it a soup
    soup = BeautifulSoup(response.text,"lxml")

    lists = soup.select(".d20f4628d0")

    lists2 = soup.select(".c8305f6688")
    
    import csv
    from csv import writer

    with open('Book1.csv', 'a', encoding='utf8', newline='') as f:
        fieldnames = ['Date', 'Hotel', 'Room Type', 'Rate']
        thewriter = csv.DictWriter(f, fieldnames=fieldnames)
        currentDateTime = datetime.datetime.now()

        
        
        for list in lists:
            hotel = list.find('div', class_='fcab3ed991 a23c043802').text
            room_type = list.find('span', class_='df597226dd').text
            room_rate = list.find('span', class_='fcab3ed991 bd73d13072').text
    
        
            thewriter.writerow({'Date': currentDateTime, 'Hotel':hotel, 'Room Type':room_type , 'Rate': room_rate})
